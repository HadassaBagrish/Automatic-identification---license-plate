# %%
# !pip install easyocr
import easyocr

# Initialize the OCR reader
reader = easyocr.Reader(['en'], gpu=False)

# Path to the image
image_path = r'4.png'  # Make sure this path is correct

# Read text from the image
results = reader.readtext(image_path)

# Print the results
for result in results:
    bbox, text, score = result
    print(f'Text: {text}, Score: {score}')
# Out:
# Collecting easyocr
#   Using cached easyocr-1.7.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: torch in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from easyocr) (2.3.0)
# Requirement already satisfied: torchvision>=0.5 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from easyocr) (0.18.0)
# Collecting opencv-python-headless (from easyocr)
#   Using cached opencv_python_headless-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: scipy in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from easyocr) (1.13.0)
# Requirement already satisfied: numpy in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from easyocr) (1.26.4)
# Requirement already satisfied: Pillow in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from easyocr) (10.3.0)
# Collecting scikit-image (from easyocr)
#   Downloading scikit_image-0.23.2-cp311-cp311-win_amd64.whl.metadata (14 kB)
# Collecting python-bidi (from easyocr)
#   Using cached python_bidi-0.4.2-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: PyYAML in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from easyocr) (6.0.1)
# Collecting Shapely (from easyocr)
#   Downloading shapely-2.0.4-cp311-cp311-win_amd64.whl.metadata (7.2 kB)
# Collecting pyclipper (from easyocr)
#   Downloading pyclipper-1.3.0.post5-cp311-cp311-win_amd64.whl.metadata (9.2 kB)
# Collecting ninja (from easyocr)
#   Using cached ninja-1.11.1.1-py2.py3-none-win_amd64.whl.metadata (5.4 kB)
# Requirement already satisfied: filelock in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch->easyocr) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch->easyocr) (4.9.0)
# Requirement already satisfied: sympy in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch->easyocr) (1.12)
# Requirement already satisfied: networkx in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch->easyocr) (3.3)
# Requirement already satisfied: jinja2 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch->easyocr) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch->easyocr) (2024.5.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch->easyocr) (2021.4.0)
# Requirement already satisfied: six in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: imageio>=2.33 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-image->easyocr) (2.34.1)
# Collecting tifffile>=2022.8.12 (from scikit-image->easyocr)
#   Using cached tifffile-2024.5.10-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: packaging>=21 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-image->easyocr) (23.2)
# Collecting lazy-loader>=0.4 (from scikit-image->easyocr)
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->easyocr) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->easyocr) (2021.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jinja2->torch->easyocr) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sympy->torch->easyocr) (1.3.0)
# Using cached easyocr-1.7.1-py3-none-any.whl (2.9 MB)
# Using cached ninja-1.11.1.1-py2.py3-none-win_amd64.whl (312 kB)
# Using cached opencv_python_headless-4.9.0.80-cp37-abi3-win_amd64.whl (38.5 MB)
# Downloading pyclipper-1.3.0.post5-cp311-cp311-win_amd64.whl (108 kB)
#    ---------------------------------------- 0.0/108.3 kB ? eta -:--:--
#    ----------- ---------------------------- 30.7/108.3 kB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 102.4/108.3 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 108.3/108.3 kB 1.0 MB/s eta 0:00:00
# Using cached python_bidi-0.4.2-py2.py3-none-any.whl (30 kB)
# Downloading scikit_image-0.23.2-cp311-cp311-win_amd64.whl (12.7 MB)
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    ---------------------------------------- 0.2/12.7 MB 4.6 MB/s eta 0:00:03
#     --------------------------------------- 0.2/12.7 MB 2.8 MB/s eta 0:00:05
#    - -------------------------------------- 0.6/12.7 MB 4.5 MB/s eta 0:00:03
#    --- ------------------------------------ 1.0/12.7 MB 5.5 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.4/12.7 MB 6.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.8/12.7 MB 6.7 MB/s eta 0:00:02
#    ------ --------------------------------- 2.1/12.7 MB 6.8 MB/s eta 0:00:02
#    -------- ------------------------------- 2.6/12.7 MB 7.1 MB/s eta 0:00:02
#    --------- ------------------------------ 3.0/12.7 MB 7.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.4/12.7 MB 7.4 MB/s eta 0:00:02
#    ------------ --------------------------- 3.8/12.7 MB 7.2 MB/s eta 0:00:02
#    ------------ --------------------------- 4.1/12.7 MB 6.8 MB/s eta 0:00:02
#    ------------- -------------------------- 4.3/12.7 MB 6.7 MB/s eta 0:00:02
#    -------------- ------------------------- 4.5/12.7 MB 6.5 MB/s eta 0:00:02
#    -------------- ------------------------- 4.7/12.7 MB 6.4 MB/s eta 0:00:02
#    --------------- ------------------------ 4.9/12.7 MB 6.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.2/12.7 MB 6.3 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.5/12.7 MB 6.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.6/12.7 MB 6.1 MB/s eta 0:00:02
#    ------------------ --------------------- 5.9/12.7 MB 6.0 MB/s eta 0:00:02
#    ------------------- -------------------- 6.1/12.7 MB 6.0 MB/s eta 0:00:02
#    -------------------- ------------------- 6.4/12.7 MB 6.0 MB/s eta 0:00:02
#    -------------------- ------------------- 6.7/12.7 MB 6.0 MB/s eta 0:00:02
#    --------------------- ------------------ 6.9/12.7 MB 6.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.3/12.7 MB 6.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.6/12.7 MB 6.0 MB/s eta 0:00:01
#    ------------------------ --------------- 7.9/12.7 MB 6.1 MB/s eta 0:00:01
#    ------------------------- -------------- 8.2/12.7 MB 6.1 MB/s eta 0:00:01
#    -------------------------- ------------- 8.5/12.7 MB 6.1 MB/s eta 0:00:01
#    --------------------------- ------------ 8.9/12.7 MB 6.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.2/12.7 MB 6.2 MB/s eta 0:00:01
#    ------------------------------ --------- 9.6/12.7 MB 6.2 MB/s eta 0:00:01
#    ------------------------------- -------- 9.9/12.7 MB 6.3 MB/s eta 0:00:01
#    ------------------------------- -------- 10.2/12.7 MB 6.3 MB/s eta 0:00:01
#    -------------------------------- ------- 10.5/12.7 MB 6.4 MB/s eta 0:00:01
#    --------------------------------- ------ 10.7/12.7 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.0/12.7 MB 6.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.2/12.7 MB 6.1 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.7 MB 5.8 MB/s eta 0:00:01
#    -------------------------------------- - 12.1/12.7 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------  12.4/12.7 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------  12.7/12.7 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------  12.7/12.7 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------  12.7/12.7 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.7/12.7 MB 5.3 MB/s eta 0:00:00
# Downloading shapely-2.0.4-cp311-cp311-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.4 MB 9.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.6/1.4 MB 7.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.9/1.4 MB 6.8 MB/s eta 0:00:01
#    ------------------------------ --------- 1.1/1.4 MB 6.4 MB/s eta 0:00:01
#    -------------------------------------- - 1.4/1.4 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  1.4/1.4 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 5.4 MB/s eta 0:00:00
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Using cached tifffile-2024.5.10-py3-none-any.whl (225 kB)
# Installing collected packages: pyclipper, ninja, tifffile, Shapely, python-bidi, opencv-python-headless, lazy-loader, scikit-image, easyocr
# Successfully installed Shapely-2.0.4 easyocr-1.7.1 lazy-loader-0.4 ninja-1.11.1.1 opencv-python-headless-4.9.0.80 pyclipper-1.3.0.post5 python-bidi-0.4.2 scikit-image-0.23.2 tifffile-2024.5.10
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 2
#       1 get_ipython().system('pip install easyocr')
# ----> 2 import easyocr
#       4 # Initialize the OCR reader
#       5 reader = easyocr.Reader(['en'], gpu=False)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\easyocr\__init__.py:1
# ----> 1 from .easyocr import Reader
#       3 __version__ = '1.7.1'
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\easyocr\easyocr.py:3
#       1 # -*- coding: utf-8 -*-
# ----> 3 from .recognition import get_recognizer, get_text
#       4 from .utils import group_text_box, get_image_list, calculate_md5, get_paragraph,\
#       5                    download_and_unzip, printProgressBar, diff, reformat_input,\
#       6                    make_rotated_img_list, set_result_with_confidence,\
#       7                    reformat_input_batched, merge_to_free
#       8 from .config import *
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\easyocr\recognition.py:2
#       1 from PIL import Image
# ----> 2 import torch
#       3 import torch.backends.cudnn as cudnn
#       4 import torch.utils.data
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\__init__.py:141
#     139                 err = ctypes.WinError(ctypes.get_last_error())
#     140                 err.strerror += f' Error loading "{dll}" or one of its dependencies.'
# --> 141                 raise err
#     143     kernel32.SetErrorMode(prev_error_mode)
#     146 def _preload_cuda_deps(lib_folder, lib_name):
#
# OSError: [WinError 126] The specified module could not be found. Error loading "C:\Users\בגריש\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\lib\shm.dll" or one of its dependencies.

# %%
# !pip install ultralytics
from ultralytics import YOLO
model = YOLO('yolov8n.yaml')
results = model.train(data='config.yaml', epochs=100)
# Out:
# Requirement already satisfied: ultralytics in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (8.0.3)
# Requirement already satisfied: hydra-core>=1.2.0 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (1.3.2)
# Requirement already satisfied: matplotlib>=3.2.2 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (3.9.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: opencv-python>=4.1.1 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (10.3.0)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (1.13.0)
# Requirement already satisfied: torch>=1.7.0 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (2.3.0)
# Collecting torchvision>=0.8.1 (from ultralytics)
#   Using cached torchvision-0.18.0-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: tensorboard>=2.4.1 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (2.16.2)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ipython in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (8.21.0)
# Requirement already satisfied: psutil in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (5.9.8)
# Requirement already satisfied: thop>=0.1.1 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: GitPython>=3.1.24 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ultralytics) (3.1.43)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from GitPython>=3.1.24->ultralytics) (4.0.11)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from hydra-core>=1.2.0->ultralytics) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from hydra-core>=1.2.0->ultralytics) (4.9.3)
# Requirement already satisfied: packaging in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from hydra-core>=1.2.0->ultralytics) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.2.2->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.2.2->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.2.2->ultralytics) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.2.2->ultralytics) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.2.2->ultralytics) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.2.2->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.23.0->ultralytics) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: absl-py>=0.4 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard>=2.4.1->ultralytics) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard>=2.4.1->ultralytics) (1.60.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard>=2.4.1->ultralytics) (3.5.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard>=2.4.1->ultralytics) (4.25.3)
# Requirement already satisfied: setuptools>=41.0.0 in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.11_3.11.2288.0_x64__qbz5n2kfra8p0\lib\site-packages (from tensorboard>=2.4.1->ultralytics) (65.5.0)
# Requirement already satisfied: six>1.9 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard>=2.4.1->ultralytics) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard>=2.4.1->ultralytics) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard>=2.4.1->ultralytics) (3.0.1)
# Requirement already satisfied: filelock in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.7.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.7.0->ultralytics) (4.9.0)
# Requirement already satisfied: sympy in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.7.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.7.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.7.0->ultralytics) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.7.0->ultralytics) (2024.5.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.7.0->ultralytics) (2021.4.0)
# Requirement already satisfied: colorama in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: decorator in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ultralytics) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ultralytics) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ultralytics) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ultralytics) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ultralytics) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ultralytics) (0.6.3)
# Requirement already satisfied: traitlets>=5 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ultralytics) (5.14.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from gitdb<5,>=4.0.1->GitPython>=3.1.24->ultralytics) (5.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jedi>=0.16->ipython->ultralytics) (0.8.3)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.7.0->ultralytics) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.7.0->ultralytics) (2021.12.0)
# Requirement already satisfied: wcwidth in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->ultralytics) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->ultralytics) (2.1.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack-data->ipython->ultralytics) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack-data->ipython->ultralytics) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack-data->ipython->ultralytics) (0.2.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\בגריש\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sympy->torch>=1.7.0->ultralytics) (1.3.0)
# Using cached torchvision-0.18.0-cp311-cp311-win_amd64.whl (1.2 MB)
# Installing collected packages: torchvision
# Successfully installed torchvision-0.18.0
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 2
#       1 get_ipython().system('pip install ultralytics')
# ----> 2 from ultralytics import YOLO
#       3 model = YOLO('yolov8n.yaml')
#       4 results = model.train(data='config.yaml', epochs=100)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\__init__.py:5
#       1 # Ultralytics YOLO 🚀, GPL-3.0 license
#       3 __version__ = "8.0.3"
# ----> 5 from ultralytics.hub import checks
#       6 from ultralytics.yolo.engine.model import YOLO
#       7 from ultralytics.yolo.utils import ops
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\hub\__init__.py:10
#       7 import requests
#       8 from IPython import display  # to display images and clear console output
# ---> 10 from ultralytics.hub.auth import Auth
#      11 from ultralytics.hub.session import HubTrainingSession
#      12 from ultralytics.hub.utils import PREFIX, split_key
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\hub\auth.py:5
#       1 # Ultralytics YOLO 🚀, GPL-3.0 license
#       3 import requests
# ----> 5 from ultralytics.hub.utils import HUB_API_ROOT, request_with_credentials
#       6 from ultralytics.yolo.utils import is_colab
#       8 API_KEY_PATH = "https://hub.ultralytics.com/settings?tab=api+keys"
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\hub\utils.py:10
#       6 import time
#       8 import requests
# ---> 10 from ultralytics.yolo.utils import DEFAULT_CONFIG_DICT, LOGGER, RANK, SETTINGS, TryExcept, colorstr, emojis
#      12 PREFIX = colorstr('Ultralytics: ')
#      13 HELP_MSG = 'If this issue persists please visit https://github.com/ultralytics/hub/issues for assistance.'
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\yolo\__init__.py:3
#       1 # Ultralytics YOLO 🚀, GPL-3.0 license
# ----> 3 from . import v8
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\yolo\v8\__init__.py:5
#       1 # Ultralytics YOLO 🚀, GPL-3.0 license
#       3 from pathlib import Path
# ----> 5 from ultralytics.yolo.v8 import classify, detect, segment
#       7 ROOT = Path(__file__).parents[0]  # yolov8 ROOT
#       9 __all__ = ["classify", "segment", "detect"]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\yolo\v8\classify\__init__.py:3
#       1 # Ultralytics YOLO 🚀, GPL-3.0 license
# ----> 3 from ultralytics.yolo.v8.classify.predict import ClassificationPredictor, predict
#       4 from ultralytics.yolo.v8.classify.train import ClassificationTrainer, train
#       5 from ultralytics.yolo.v8.classify.val import ClassificationValidator, val
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\yolo\v8\classify\predict.py:4
#       1 # Ultralytics YOLO 🚀, GPL-3.0 license
#       3 import hydra
# ----> 4 import torch
#       6 from ultralytics.yolo.engine.predictor import BasePredictor
#       7 from ultralytics.yolo.utils import DEFAULT_CONFIG, ROOT
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\__init__.py:141
#     139                 err = ctypes.WinError(ctypes.get_last_error())
#     140                 err.strerror += f' Error loading "{dll}" or one of its dependencies.'
# --> 141                 raise err
#     143     kernel32.SetErrorMode(prev_error_mode)
#     146 def _preload_cuda_deps(lib_folder, lib_name):
#
# OSError: [WinError 126] The specified module could not be found. Error loading "C:\Users\בגריש\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\lib\shm.dll" or one of its dependencies.

# %%
from ultralytics import YOLO
import cv2

import util
from sort.sort import *
from util import get_car, read_license_plate, write_csv


results = {}

mot_tracker = Sort()

# load models
coco_model = YOLO('yolov8n.pt')
license_plate_detector = YOLO('models/license_plate_detector.pt')

# load video
cap = cv2.VideoCapture('./sample.mp4')

vehicles = [2, 3, 5, 7]

# read frames
frame_nmr = -1
ret = True
while ret:
    frame_nmr += 1
    ret, frame = cap.read()
    if ret:
        results[frame_nmr] = {}
        # detect vehicles
        detections = coco_model(frame)[0]
        detections_ = []
        for detection in detections.boxes.data.tolist():
            x1, y1, x2, y2, score, class_id = detection
            if int(class_id) in vehicles:
                detections_.append([x1, y1, x2, y2, score])

        # track vehicles
        track_ids = mot_tracker.update(np.asarray(detections_))

        # detect license plates
        license_plates = license_plate_detector(frame)[0]
        for license_plate in license_plates.boxes.data.tolist():
            x1, y1, x2, y2, score, class_id = license_plate

            # assign license plate to car
            xcar1, ycar1, xcar2, ycar2, car_id = get_car(license_plate, track_ids)

            if car_id != -1:

                # crop license plate
                license_plate_crop = frame[int(y1):int(y2), int(x1): int(x2), :]

                # process license plate
                license_plate_crop_gray = cv2.cvtColor(license_plate_crop, cv2.COLOR_BGR2GRAY)
                _, license_plate_crop_thresh = cv2.threshold(license_plate_crop_gray, 64, 255, cv2.THRESH_BINARY_INV)

                # read license plate number
                license_plate_text, license_plate_text_score = read_license_plate(license_plate_crop_thresh)

                if license_plate_text is not None:
                    results[frame_nmr][car_id] = {'car': {'bbox': [xcar1, ycar1, xcar2, ycar2]},
                                                  'license_plate': {'bbox': [x1, y1, x2, y2],
                                                                    'text': license_plate_text,
                                                                    'bbox_score': score,
                                                                    'text_score': license_plate_text_score}}

# write results
write_csv(results, './test.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from ultralytics import YOLO
#       2 import cv2
#       4 import util
#
# ModuleNotFoundError: No module named 'ultralytics'

# %%
from ultralytics import YOLO

# Download and load the YOLOv8 pre-trained model
coco_model = YOLO('yolov8n.pt')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 from ultralytics import YOLO
#       3 # Download and load the YOLOv8 pre-trained model
#       4 coco_model = YOLO('yolov8n.pt')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\__init__.py:5
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
#       3 __version__ = "8.2.18"
# ----> 5 from ultralytics.data.explorer.explorer import Explorer
#       6 from ultralytics.models import RTDETR, SAM, YOLO, YOLOWorld
#       7 from ultralytics.models.fastsam import FastSAM
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\data\__init__.py:3
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
# ----> 3 from .base import BaseDataset
#       4 from .build import build_dataloader, build_grounding, build_yolo_dataset, load_inference_source
#       5 from .dataset import (
#       6     ClassificationDataset,
#       7     GroundingDataset,
#    (...)
#      11     YOLOMultiModalDataset,
#      12 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\data\base.py:15
#      13 import numpy as np
#      14 import psutil
# ---> 15 from torch.utils.data import Dataset
#      17 from ultralytics.data.utils import FORMATS_HELP_MSG, HELP_URL, IMG_FORMATS
#      18 from ultralytics.utils import DEFAULT_CFG, LOCAL_RANK, LOGGER, NUM_THREADS, TQDM
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\__init__.py:4
#       1 import os.path as _osp
#       2 import sys
# ----> 4 from .throughput_benchmark import ThroughputBenchmark
#       5 from ._crash_handler import enable_minidumps, disable_minidumps, enable_minidumps_on_exceptions
#       6 from .cpp_backtrace import get_cpp_backtrace
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\throughput_benchmark.py:2
# ----> 2 import torch._C
#       5 def format_time(time_us=None, time_ms=None, time_s=None):
#       6     '''Defines how to format time'''
#
# ImportError: DLL load failed while importing _C: The specified module could not be found.

# %%
# !python predict.py model='best.pt' source='roboflow.mp4'
# Out:
# Traceback (most recent call last):
#   File "g:\פרויקט שנתי\AAAProject\ניסוי אחרון\predict.py", line 6, in <module>
#     from ultralytics.yolo.engine.predictor import BasePredictor
#   File "C:\Users\בגריש\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\__init__.py", line 5, in <module>
#     from ultralytics.hub import checks
#   File "C:\Users\בגריש\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\hub\__init__.py", line 10, in <module>
#     from ultralytics.hub.auth import Auth
#   File "C:\Users\בגריש\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\hub\auth.py", line 5, in <module>
#     from ultralytics.hub.utils import HUB_API_ROOT, request_with_credentials
#   File "C:\Users\בגריש\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\hub\utils.py", line 10, in <module>
#     from ultralytics.yolo.utils import DEFAULT_CONFIG_DICT, LOGGER, RANK, SETTINGS, TryExcept, colorstr, emojis
#   File "C:\Users\בגריש\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\yolo\__init__.py", line 3, in <module>
#     from . import v8
#   File "C:\Users\בגריש\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\yolo\v8\__init__.py", line 5, in <module>
#     from ultralytics.yolo.v8 import classify, detect, segment
#   File "C:\Users\בגריש\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\yolo\v8\classify\__init__.py", line 3, in <module>
#     from ultralytics.yolo.v8.classify.predict import ClassificationPredictor, predict
#   File "C:\Users\בגריש\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\yolo\v8\classify\predict.py", line 6, in <module>
#     from ultralytics.yolo.engine.predictor import BasePredictor
#   File "C:\Users\בגריש\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\yolo\engine\predictor.py", line 34, in <module>
#     from ultralytics.nn.autobackend import AutoBackend
#   File "C:\Users\בגריש\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ultralytics\nn\autobackend.py", line 12, in <module>
#     import torch.nn as nn
#   File "C:\Users\בגריש\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
#     ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\בגריש\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\__init__.py", line 1, in <module>
#     from .module import Module
#   File "C:\Users\בגריש\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py", line 8, in <module>
#     from torch._prims_common import DeviceLikeType
# ModuleNotFoundError: No module named 'torch._prims_common'
